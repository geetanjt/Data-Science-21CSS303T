# %% [markdown]
#             # HISTOGRAM

# %% [markdown]
# We can create a histogram in Matplotlib using the hist() function. This function allows us to customize various aspects of the histogram, such as the number of bins, color, and transparency. Histogram in Matplotlib is used to represent the distribution of numerical data, helping you to identify patterns.
#
#     The hist() function in Matplotlib takes a dataset as input and divides it into intervals (bins). It then displays the frequency (count) of data points falling within each bin as a bar graph.

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
import random

# %%
age_cs=np.random.randint(18,35,(70))
age_cc=np.random.randint(18,36,(40))

# %%
print(age_cs)
print(age_cc)
# Out:
# [34 25 19 18 28 23 33 29 18 31 27 20 31 25 28 31 30 19 22 22 32 26 29 30
#  28 31 19 19 25 31 28 20 34 19 30 18 20 25 19 20 34 32 30 31 19 27 25 27
#  32 34 20 31 25 18 33 29 26 27 27 29 30 21 25 28 25 19 19 31 21 20]
# [24 27 21 23 32 20 19 27 26 19 21 26 22 31 35 29 34 33 22 19 33 28 33 26
#  24 27 26 33 35 31 24 24 22 25 18 30 35 18 21 26]

# %%
style.use('ggplot')
plt.hist(age_cs,bins=[15,20,25,30,35],rwidth=0.4,histtype="bar")
plt.title('CYBER STUDENTS')
plt.xlabel('students age category')
plt.ylabel('no of students')
plt.show()

# %%
plt.hist([age_cs, age_cc], rwidth=0.8, histtype = "bar",
         orientation='vertical', color = ["m", "y"], label = ["cs Student", "cc Student"])
plt.title('CYBER STUDENTS')
plt.xlabel('students age category')
plt.ylabel('no of students')
plt.axvline(25,color='g',label='line')
plt.legend()
plt.show()
